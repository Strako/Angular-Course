# %% [markdown]
# <a href="https://colab.research.google.com/github/Strako/Angular-Course/blob/main/Practica2.1%20Neurona.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
def genRandom():
  return random.uniform(-10,10)

def summation(x,w,offset):
  result = 0
  for i in range(0,2):
    result = result + x[i+offset] * w[i]
    print("Values of summation --- "," Input: ",x[i+offset]," Weight: ", w[i])
  if(condition):
    print("summation result",result)
  return result

offset = [0,2,4]
x = [0,0,0,1,1,1]
w = [0,0]
s = 0
y = 0
results = [False,False,False]
condition = True;

while(condition):
  w[0]=genRandom()
  w[1]=genRandom()
  for z in range(0,3):
    print("value of Z:",z)
    s = summation(x,w,offset[z])
    y = (0, 1)[s>0]
    if(z == 0 and y == 0):
      results[z] = True
    elif(z == 0 and y == 1):
      results[z] = False
    if(z == 1 and y == 0):
      results[z] = True
    elif(z == 1 and y == 1):
      results[z] = False
    if(z == 2 and y == 1):
      results[z] = True
    elif(z == 2 and y == 0):
      results[z] = False

  if(results[0] and results[1] and results[2]):
    condition = False


  print("Results array: ",results)
  print("Generated weights: ",w[0], 'AND', w[1], '=', y )

if(not condition):
    print("\n\n\n\n\n----------------    Correct weights: ",w[0], 'AND', w[1],"    ----------------")
    print("Case 1 (0,0), Case 2 (0,1), Case 3 (1,1)")
    for z in range(0,3):
      print("\nCase: ",z + 1)
      s = summation(x,w,offset[z])
      y = (0, 1)[s>0]
      print("Net input function: ",s)
      print("Activation function: ", y )
# Out:
# value of Z: 0
# Values of summation ---   Input:  0  Weight:  -3.8615573079853993
# Values of summation ---   Input:  0  Weight:  7.657232054501492
# summation result 0.0
# value of Z: 1
# Values of summation ---   Input:  0  Weight:  -3.8615573079853993
# Values of summation ---   Input:  1  Weight:  7.657232054501492
# summation result 7.657232054501492
# value of Z: 2
# Values of summation ---   Input:  1  Weight:  -3.8615573079853993
# Values of summation ---   Input:  1  Weight:  7.657232054501492
# summation result 3.7956747465160925
# Results array:  [True, False, True]
# Generated weights:  -3.8615573079853993 AND 7.657232054501492 = 1
# value of Z: 0
# Values of summation ---   Input:  0  Weight:  -2.0500291472004584
# Values of summation ---   Input:  0  Weight:  0.32407058973670466
# summation result 0.0
# value of Z: 1
# Values of summation ---   Input:  0  Weight:  -2.0500291472004584
# Values of summation ---   Input:  1  Weight:  0.32407058973670466
# ...
